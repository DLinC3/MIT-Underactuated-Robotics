# %% [markdown]
# This notebook provides examples to go along with the [textbook](https://underactuated.csail.mit.edu/lyapunov.html).  I recommend having both windows open, side-by-side!

# %%
import matplotlib.pyplot as plt
import mpld3
import numpy as np
from IPython.display import display
from pydrake.all import (
    MakeVectorContinuousVariable,
    MathematicalProgram,
    RealContinuousLyapunovEquation,
    RegionOfAttraction,
    Solve,
    SymbolicVectorSystem,
    Variable,
    Variables,
    plot_sublevelset_expression,
)
from pydrake.examples import VanDerPolOscillator

from underactuated import plot_2d_phase_portrait, running_as_notebook

if running_as_notebook:
    mpld3.enable_notebook()

# %% [markdown]
# # Time-reversed van der Pol Oscillator
#
# We also use this example in the exercises at the end of the Lyapunov chapter, and work through all of the details of the formulation.  I highly recommend you try it out!
#
# N.B. -- we know how to get much larger/tighter (inner) approximations of this RoA.  I will be implementing those ideas in drake's RegionOfAttraction method very soon.  Hopefully the region will be even bigger next time you try it.

# %%
def vdp_roa():
    x1 = Variable("x1")
    x2 = Variable("x2")
    sys = SymbolicVectorSystem(state=[x1, x2], dynamics=[-x2, x1 + (x1 * x1 - 1) * x2])
    context = sys.CreateDefaultContext()
    V = RegionOfAttraction(system=sys, context=context)

    fig, ax = plt.subplots(figsize=(10, 10))
    plot_2d_phase_portrait(sys, (-3, 3), (-3, 3))
    limit_cycle = VanDerPolOscillator.CalcLimitCycle()
    plt.plot(
        limit_cycle[0],
        limit_cycle[1],
        color="k",
        linewidth=3,
        label="Known ROA boundary",
    )
    plt.legend(loc=1)
    plot_sublevelset_expression(ax, V)
    display(mpld3.display())


vdp_roa()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el4437af11a852-ddae-4e0f-964c-58c38fb0b309658949766"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el4437af11a852-ddae-4e0f-964c-58c38fb0b309658949766", {"width": 1000.0, "height": 1000.0, "axes": [{"bbox": [0.125, 0.18499999999999994, 0.6200000000000001, 0.6200000000000001], "xlim": [-3.0, 3.0], "ylim": [-3.0, 3.0], "xdomain": [-3.0, 3.0], "ydomain": [-3.0, 3.0], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el4437a9ced82f-c4ac-4aa3-ad09-bf9cfd26a325", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el44376e2c84b2-d691-4504-8d83-f71631e7f2c3", "color": "#000000", "linewidth": 3.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data71", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el443728dc09ff-e345-4b91-a7f6-d877fc710e14", "color": "#000000", "linewidth": 3.0, "dasharray": "none", "alpha": 1, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el44376b016dac-2ceb-4a71-9115-1a4469354a2a", "dasharray": "none", "alpha": 1, "facecolor": "#33B679", "edgecolor": "#33B679", "edgewidth": 1.5, "zorder": 2}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el443743ca0b46-fe93-44eb-9e9b-1a1679b5364a", "dasharray": "none", "alpha": 1, "facecolor": "#482273", "edgecolor": "#482273", "edgewidth": 1.5, "zorder": 2}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el443727e634ce-9356-460f-8f5c-65d3ca4e0c59", "dasharray": "none", "alpha": 1, "facecolor": "#355D8C", "edgecolor": "#355D8C", "edgewidth": 1.5, "zorder": 2}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el44371262c2f2-1957-4c87-a075-0e52bc1d8a60", "dasharray": "none", "alpha": 1, "facecolor": "#3C4E8A", "edgecolor": "#3C4E8A", "edgewidth": 1.5, "zorder": 2}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el44377d990d63-d74d-43f0-9270-ced727fee56f", "dasharray": "none", "alpha": 1, "facecolor": "#423D84", "edgecolor": "#423D84", "edgewidth": 1.5, "zorder": 2}, {"data": "data07", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el4437baa80a72-8ce3-4282-8cb2-dc2b2a3cdab6", "dasharray": "none", "alpha": 1, "facecolor": "#48196B", "edgecolor": "#48196B", "edgewidth": 1.5, "zorder": 2}, {"data": "data08", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el4437f60177f1-22df-498d-90c5-ef335d2f9774", "dasharray": "none", "alpha": 1, "facecolor": "#481E70", "edgecolor": "#481E70", "edgewidth": 1.5, "zorder": 2}, {"data": "data09", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el44372781d3a5-8986-48b4-b996-dde8968f9d5c", "dasharray": "none", "alpha": 1, "facecolor": "#46317E", "edgecolor": "#46317E", "edgewidth": 1.5, "zorder": 2}, {"data": "data10", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el4437d4b9f0d3-2f56-4a42-80e0-7895bb30e2f7", "dasharray": "none", "alpha": 1, "facecolor": "#482071", "edgecolor": "#482071", "edgewidth": 1.5, "zorder": 2}, {"data": "data11", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el44379154a3d3-7c28-45bf-a329-ddf307138b06", "dasharray": "no ...

# %% [markdown]
# # Searching for the Lyapunov function
#
# The previous example used the linearization to propose a candidate Lyapunov function, and SOS optimization to verify the largest possible sublevel set of that function. We can do better if allow the optimization to also change the parameters of the Lyapunov function. But this problem is non-convex, so we use bilinear alternations.

# %%
# TODO(russt): Generalize this example to non-quadratic Lyapunov functions.
# TODO(russt): Improve the numerics (e.g. BalanceQuadraticForms, etc)

from pydrake.all import MosekSolver, ScsSolver


def vdp_roa_optimize_quadratic():
    # Clarabel v0.9.0 fails to solve this problem.
    # See https://github.com/oxfordcontrol/Clarabel.rs/issues/119
    solver = (
        MosekSolver()
        if (MosekSolver().available() and MosekSolver().enabled())
        else ScsSolver()
    )

    # function that implements the time-reversed Van der Pol dynamics
    f = lambda x: [-x[1], x[0] + (x[0] ** 2 - 1) * x[1]]

    def OptimizeMultipliers(x, P, lambda_degree=4):
        prog = MathematicalProgram()
        prog.AddIndeterminates(x)

        V = x.dot(P).dot(x)
        Vdot = V.Jacobian(x).dot(f(x))

        l = prog.NewFreePolynomial(Variables(x), lambda_degree).ToExpression()
        rho = prog.NewContinuousVariables(1, "rho")[0]

        prog.AddSosConstraint(x.dot(x) * (V - rho) - l * Vdot)

        prog.AddLinearCost(-rho)

        result = solver.Solve(prog)
        assert result.is_success()

        return result.GetSolution(l), P / result.GetSolution(rho)

    def OptimizeLyapunov(x, Phat, l):
        prog = MathematicalProgram()
        prog.AddIndeterminates(x)
        P = prog.NewSymmetricContinuousVariables(2, "P")

        prog.AddLinearCost(np.trace(np.linalg.inv(Phat) @ P))

        V = x.dot(P).dot(x)
        Vdot = V.Jacobian(x).dot(f(x))

        prog.AddSosConstraint(x.dot(x) * (V - 1) - l * Vdot)
        prog.AddPositiveSemidefiniteConstraint(P)

        result = solver.Solve(prog)
        assert result.is_success()

        return result.GetSolution(P)

    x = MakeVectorContinuousVariable(2, "x")
    A = np.array([[0, -1], [1, -1]])
    Q = np.eye(2)
    P = RealContinuousLyapunovEquation(A, Q)
    print(f"P = {P}")
    l, P = OptimizeMultipliers(x, P)
    P_last = np.eye(2)
    while np.linalg.norm(P - P_last) > 1e-3:
        P_last = P
        P = OptimizeLyapunov(x, P, l)
        l, P = OptimizeMultipliers(x, P)
        print(f"P = {P}")

    fig, ax = plt.subplots(figsize=(10, 10))
    sys = SymbolicVectorSystem(state=x, dynamics=f(x))
    plot_2d_phase_portrait(sys, (-3, 3), (-3, 3))
    limit_cycle = VanDerPolOscillator.CalcLimitCycle()
    plt.plot(
        limit_cycle[0],
        limit_cycle[1],
        color="k",
        linewidth=3,
        label="Known ROA boundary",
    )
    plt.legend(loc=1)
    V = x.dot(P).dot(x)
    plot_sublevelset_expression(ax, V)
    display(mpld3.display())


vdp_roa_optimize_quadratic()
# Out:
# P = [[ 1.5 -0.5]
#  [-0.5  1. ]]
# P = [[ 0.65000985 -0.21683799]
#  [-0.21683799  0.43362309]]
# <style>
#
# </style>
#
# <div id="fig_el4437d738f719-ea55-4dd6-9841-2a68c4156e346170205933"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el4437d738f719-ea55-4dd6-9841-2a68c4156e346170205933", {"width": 1000.0, "height": 1000.0, "axes": [{"bbox": [0.125, 0.18499999999999994, 0.6200000000000001, 0.6200000000000001], "xlim": [-3.0, 3.0], "ylim": [-3.0, 3.0], "xdomain": [-3.0, 3.0], "ydomain": [-3.0, 3.0], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el443716a00b11-277a-4a48-9392-6e7f87c44fab", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el443723d9c0b2-dd76-4a10-9b4c-7028371bd13b", "color": "#000000", "linewidth": 3.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data71", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el44378651f781-a462-448e-9674-cd275997f1c4", "color": "#000000", "linewidth": 3.0, "dasharray": "none", "alpha": 1, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el4437fe9828f3-f77a-46b6-bf38-485cba16e67d", "dasharray": "none", "alpha": 1, "facecolor": "#33B679", "edgecolor": "#33B679", "edgewidth": 1.5, "zorder": 2}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el44372eedf80d-ae9b-4d34-836d-8f160601ec9d", "dasharray": "none", "alpha": 1, "facecolor": "#482273", "edgecolor": "#482273", "edgewidth": 1.5, "zorder": 2}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el4437788c2d4e-1887-4138-aaa8-c4e13a5f10ac", "dasharray": "none", "alpha": 1, "facecolor": "#355D8C", "edgecolor": "#355D8C", "edgewidth": 1.5, "zorder": 2}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el44373868f3ca-7a9e-4326-ac86-2dab1fd913a3", "dasharray": "none", "alpha": 1, "facecolor": "#3C4E8A", "edgecolor": "#3C4E8A", "edgewidth": 1.5, "zorder": 2}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el44370747d542-2ffa-4527-b106-9b0313a74b31", "dasharray": "none", "alpha": 1, "facecolor": "#423D84", "edgecolor": "#423D84", "edgewidth": 1.5, "zorder": 2}, {"data": "data07", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el4437adc8e2b2-0df5-4ce3-be43-bb279da38b60", "dasharray": "none", "alpha": 1, "facecolor": "#48196B", "edgecolor": "#48196B", "edgewidth": 1.5, "zorder": 2}, {"data": "data08", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el4437d27afd5b-dd0c-458e-aae5-343480e52e0b", "dasharray": "none", "alpha": 1, "facecolor": "#481E70", "edgecolor": "#481E70", "edgewidth": 1.5, "zorder": 2}, {"data": "data09", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el4437f5dedfef-af77-44b1-a579-ced450367126", "dasharray": "none", "alpha": 1, "facecolor": "#46317E", "edgecolor": "#46317E", "edgewidth": 1.5, "zorder": 2}, {"data": "data10", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el443788429846-c062-4508-9137-e02e2d269ce7", "dasharray": "none", "alpha": 1, "facecolor": "#482071", "edgecolor": "#482071", "edgewidth": 1.5, "zorder": 2}, {"data": "data11", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "S", "M", "L", "L", "Z"], "id": "el443778626fc9-b0b7-4c47-ad86-5303026b133f", "dasharray": "n ...
