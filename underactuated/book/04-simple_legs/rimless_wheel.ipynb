# %% [markdown]
# This notebook provides examples to go along with the [textbook](https://underactuated.csail.mit.edu/simple_legs.html).  I recommend having both windows open, side-by-side!

# %%
import mpld3
import numpy as np
from IPython.display import display
from matplotlib import pyplot as plt
from pydrake.all import (
    DiagramBuilder,
    MeshcatVisualizer,
    SceneGraph,
    Simulator,
    StartMeshcat,
)
from pydrake.examples import RimlessWheel, RimlessWheelGeometry, RimlessWheelParams

from underactuated import running_as_notebook

if running_as_notebook:
    mpld3.enable_notebook()

# %%
# Start the visualizer (run this cell only once, each instance consumes a port)
meshcat = StartMeshcat()
# Out:
# INFO:drake:Meshcat listening for connections at http://localhost:7001

# %% [markdown]
# # The Rimless Wheel

# %%
def rimless_wheel(slope=0.08, initial_angle=0, initial_angular_velocity=5.0):
    params = RimlessWheelParams()
    params.set_slope(slope)

    builder = DiagramBuilder()
    rimless_wheel = builder.AddSystem(RimlessWheel())
    scene_graph = builder.AddSystem(SceneGraph())
    RimlessWheelGeometry.AddToBuilder(
        builder,
        rimless_wheel.get_floating_base_state_output_port(),
        params,
        scene_graph,
    )
    visualizer = MeshcatVisualizer.AddToBuilder(builder, scene_graph, meshcat)
    meshcat.Set2dRenderMode(xmin=-2, xmax=14, ymin=-2, ymax=3)

    diagram = builder.Build()
    simulator = Simulator(diagram)

    context = simulator.get_mutable_context()

    diagram.GetMutableSubsystemContext(rimless_wheel, context).get_numeric_parameter(
        0
    ).set_slope(slope)
    context.SetAccuracy(1e-4)
    context.SetContinuousState([initial_angle, initial_angular_velocity])
    simulator.Initialize()
    visualizer.StartRecording(False)
    simulator.AdvanceTo(5.0 if running_as_notebook else 0.1)
    visualizer.PublishRecording()


rimless_wheel()

# %%
rimless_wheel(initial_angular_velocity=5.0)

# %%
rimless_wheel(initial_angular_velocity=10.0)

# %%
rimless_wheel(initial_angular_velocity=0.95)

# %%
rimless_wheel(initial_angular_velocity=-5.0)

# %%
rimless_wheel(initial_angular_velocity=-4.8)

# %% [markdown]
# Here is a little interactive plot to allow you to visualize the trajectories of the rimless wheel as you vary the initial velocity.

# %%
# TODO(russt): Port to meshcat and make it interactive, once again.


def rimless_wheel_return_map(initial_angular_velocity=1.5, duration=1.5):
    rimless_wheel = RimlessWheel()
    simulator = Simulator(rimless_wheel)
    context = simulator.get_mutable_context()
    params = context.get_numeric_parameter(0)
    qmin = params.slope() - rimless_wheel.calc_alpha(params) - 0.1
    qmax = params.slope() + rimless_wheel.calc_alpha(params) + 0.1
    qdmin = -2
    qdmax = 2

    context.SetAccuracy(1e-2)
    integrator = simulator.get_mutable_integrator()

    fig, ax = plt.subplots(figsize=(10, 6))

    # TODO(russt): make the slope interactive, too.
    def simulate(initial_angular_velocity=1.5, duration=1.5):
        rimless_wheel.SetDefaultContext(context)
        context.SetTime(0.0)
        if initial_angular_velocity >= 0:
            initial_angle = params.slope() - rimless_wheel.calc_alpha(params)
        else:
            initial_angle = params.slope() + rimless_wheel.calc_alpha(params)
        if initial_angular_velocity == 0:
            # Set double_support = True.
            context.get_mutable_abstract_state(0).set_value(True)

        context.SetContinuousState([initial_angle, initial_angular_velocity])

        integrator.StartDenseIntegration()
        simulator.Initialize()
        simulator.AdvanceTo(duration if running_as_notebook else 0.1)
        pp = integrator.StopDenseIntegration()

        return pp.vector_values(pp.get_segment_times())

    if False:
        data = simulate()
        (line,) = ax.plot(data[0, :], data[1, :], "b")
        (pt,) = ax.plot(data[0, 0], data[1, 0], "b*", markersize=12)

        def update(initial_angular_velocity):
            data = simulate(initial_angular_velocity)
            line.set_xdata(data[0, :])
            line.set_ydata(data[1, :])
            pt.set_xdata(data[0, 0])
            pt.set_ydata(data[1, 0])
            fig.canvas.draw()

        interact(
            update,
            initial_angular_velocity=widgets.FloatSlider(
                min=qdmin, max=qdmax, step=0.1, value=1.1
            ),
        )

    else:
        data = simulate(initial_angular_velocity, duration)
        ax.plot(data[0, :], data[1, :], "b")
        ax.plot(data[0, 0], data[1, 0], "b*", markersize=12)

    # Plot the energy contours.
    nq = 151
    nqd = 151
    mgl = params.mass() * params.gravity() * params.length()
    q = np.linspace(qmin, qmax, nq)
    qd = np.linspace(qdmin, qdmax, nqd)
    Q, QD = np.meshgrid(q, qd)
    Energy = 0.5 * params.mass() * params.length() ** 2 * QD**2 + mgl * np.cos(Q)
    ax.contour(
        Q,
        QD,
        Energy,
        alpha=0.5,
        linestyles="dashed",
        colors="black",
        linewidths=0.5,
    )

    ax.plot(
        params.slope() - rimless_wheel.calc_alpha(params) * np.array([1, 1]),
        np.array([0, qdmax]),
        "k--",
    )
    ax.plot(
        params.slope() - rimless_wheel.calc_alpha(params) * np.array([1, 1]),
        np.array([0, qdmin]),
        "k",
        linewidth=0.25,
    )
    ax.plot(
        params.slope() + rimless_wheel.calc_alpha(params) * np.array([1, 1]),
        np.array([0, qdmin]),
        "k--",
    )
    ax.plot(
        params.slope() + rimless_wheel.calc_alpha(params) * np.array([1, 1]),
        np.array([0, qdmax]),
        "k",
        linewidth=0.25,
    )
    ax.plot([qmin, qmax], [0, 0], "k", linewidth=0.25)
    ax.plot([0, 0], [qdmin, qdmax], "k", linewidth=0.25)
    ax.set_xlabel("theta")
    ax.set_ylabel("thetadot")
    ax.axis([qmin, qmax, qdmin, qdmax])
    ax.set_title(
        "Trajectories of the Rimless Wheel (w/ contours of " "constant energy)"
    )
    display(mpld3.display())


# Interesting angular velocities to try: 1.1, 1.5, 4, 1.0, 0.95, -5, -4.8
rimless_wheel_return_map(initial_angular_velocity=4, duration=5)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el4216ed5d6582-48c6-4f62-944b-83dbea0ebc883362157345"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el4216ed5d6582-48c6-4f62-944b-83dbea0ebc883362157345", {"width": 1000.0, "height": 600.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.41269908169872416, 0.5726990816987242], "ylim": [-2.0, 2.0], "xdomain": [-0.41269908169872416, 0.5726990816987242], "ydomain": [-2.0, 2.0], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el4216672a9a8d-911b-4d9a-98b7-c492d62b69fe", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el4216e28a1c07-739c-4f77-88fc-6bc855575bf5", "color": "#0000FF", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el4216b8ab59e2-2c54-41cd-b55c-a1e70b5c5d0c", "color": "#000000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el42163376024b-b417-46df-8765-a74cfb1c0471", "color": "#000000", "linewidth": 0.25, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 3, "yindex": 2, "coordinates": "data", "id": "el42167eaf7901-165a-404d-9c13-372cba2f97a3", "color": "#000000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 3, "yindex": 1, "coordinates": "data", "id": "el421671693d33-027d-48ac-addc-82d322095821", "color": "#000000", "linewidth": 0.25, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el4216d0a129f6-17fe-46ca-b616-b809a7a5ac26", "color": "#000000", "linewidth": 0.25, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 1, "yindex": 2, "coordinates": "data", "id": "el4216e532a8d6-bb57-4ea9-b129-1e12afcde62f", "color": "#000000", "linewidth": 0.25, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}], "paths": [], "markers": [{"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el42168ea16923-9825-4197-8b98-66bce14c3d26pts", "facecolor": "#0000FF", "edgecolor": "#0000FF", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[3.6739403974420594e-16, -6.0], [-1.3470838900628805, -1.854101911640527], [-5.706339097770921, -1.8541019662496852], [-2.179627519819168, 0.7082039116405268], [-3.5267115137548393, 4.854101966249684], [-4.209960953548061e-16, 2.291796], [3.5267115137548375, 4.854101966249686], [2.179627519819168, 0.7082039116405277], [5.706339097770922, -1.854101966249683], [1.3470838900628814, -1.8541019116405268]], ["M", "L", "L", "L", "L", "L", "L", "L", "L", "L", "Z"]]}], "texts": [{"text": "theta", "position": [0.5, -0.06337181337181337], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el42163854449e-fc9d-470a-9f5b-fd2ec81cbfac"}, {"text": "thetadot", "position": [-0.06310035842293907, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el421659246a87-db33-44a7-9161-a1bf1be860a2"}, {"text": "Trajectories of the Rimless Wheel (w/ contours of constant energy)", "position": [0.5, 1.018037518037518], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -0.0, "fontsize": 12.0, "color": "#000000", "alpha": 1, "zorder":  ...

# %%
rimless_wheel_return_map(initial_angular_velocity=-4.8, duration=5)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el4216df1f4665-3619-478e-a7f3-2da405df9a9f5136238538"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el4216df1f4665-3619-478e-a7f3-2da405df9a9f5136238538", {"width": 1000.0, "height": 600.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-0.41269908169872416, 0.5726990816987242], "ylim": [-2.0, 2.0], "xdomain": [-0.41269908169872416, 0.5726990816987242], "ydomain": [-2.0, 2.0], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el42167e3f7a71-f4fc-4521-83ca-2821d21ba7bc", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el4216e286b191-a610-4fe6-9aa1-46713ec4be89", "color": "#0000FF", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el4216ab1c8aef-db28-4bec-91c1-88b0340c47b2", "color": "#000000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el4216a9a19446-f3ce-434a-8e79-6c58443e67f5", "color": "#000000", "linewidth": 0.25, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 3, "yindex": 2, "coordinates": "data", "id": "el42165d6aa7dd-9274-48cf-afa6-6b61192b5e40", "color": "#000000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 3, "yindex": 1, "coordinates": "data", "id": "el42169ae21665-9a73-4777-a0c1-8a0f61dc6e4d", "color": "#000000", "linewidth": 0.25, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el4216aaf1da5e-926b-4ca1-9d9f-8b99a4e04f6f", "color": "#000000", "linewidth": 0.25, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 1, "yindex": 2, "coordinates": "data", "id": "el4216ce01a4e4-0404-48ab-9aea-ce55461df3c1", "color": "#000000", "linewidth": 0.25, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}], "paths": [], "markers": [{"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el4216d6716338-2f82-417d-8467-c73ece89db6epts", "facecolor": "#0000FF", "edgecolor": "#0000FF", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[3.6739403974420594e-16, -6.0], [-1.3470838900628805, -1.854101911640527], [-5.706339097770921, -1.8541019662496852], [-2.179627519819168, 0.7082039116405268], [-3.5267115137548393, 4.854101966249684], [-4.209960953548061e-16, 2.291796], [3.5267115137548375, 4.854101966249686], [2.179627519819168, 0.7082039116405277], [5.706339097770922, -1.854101966249683], [1.3470838900628814, -1.8541019116405268]], ["M", "L", "L", "L", "L", "L", "L", "L", "L", "L", "Z"]]}], "texts": [{"text": "theta", "position": [0.5, -0.06337181337181337], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el42169e288707-ab6b-4602-8726-dd21c64ee188"}, {"text": "thetadot", "position": [-0.06310035842293907, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4216664806a1-4270-4b6d-a43c-48b41ded2fc6"}, {"text": "Trajectories of the Rimless Wheel (w/ contours of constant energy)", "position": [0.5, 1.018037518037518], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -0.0, "fontsize": 12.0, "color": "#000000", "alpha": 1, "zorder":  ...
